# %%
# Import the dependencies.
import pandas as pd
import gmaps
import requests
import matplotlib.pyplot as plt
import numpy as np

# Import the API key.
from config import weather_api_key

# %%
# Create a new set of 2000 random latitude and longitude.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# Get the nearest city using the citypy module
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 761

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# Perform an API call with the OpenWeatherMap
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
#print(url)

# Create an empty list to hold the weather data.
city_data = []

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        weather_description = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | thompson
# Processing Record 2 of Set 1 | punta arenas
# Processing Record 3 of Set 1 | rikitea
# Processing Record 4 of Set 1 | ponta do sol
# Processing Record 5 of Set 1 | port alfred
# Processing Record 6 of Set 1 | bluff
# Processing Record 7 of Set 1 | ushuaia
# Processing Record 8 of Set 1 | hedensted
# Processing Record 9 of Set 1 | hilo
# Processing Record 10 of Set 1 | angoram
# Processing Record 11 of Set 1 | puerto ayora
# Processing Record 12 of Set 1 | jubayl
# City not found. Skipping...
# Processing Record 13 of Set 1 | cape town
# Processing Record 14 of Set 1 | nantucket
# Processing Record 15 of Set 1 | pundaguitan
# Processing Record 16 of Set 1 | pascagoula
# Processing Record 17 of Set 1 | salinopolis
# Processing Record 18 of Set 1 | busselton
# Processing Record 19 of Set 1 | kruisfontein
# Processing Record 20 of Set 1 | wuzhou
# Processing Record 21 of Set 1 | alyangula
# Processing Record 22 of Set 1 | hailar
# Processing Record 23 of Set 1 | port blair
# Processing Record 24 of Set 1 | tigil
# Processing Record 25 of Set 1 | saskylakh
# Processing Record 26 of Set 1 | shakawe
# Processing Record 27 of Set 1 | geraldton
# Processing Record 28 of Set 1 | meadow lake
# Processing Record 29 of Set 1 | chore
# City not found. Skipping...
# Processing Record 30 of Set 1 | salalah
# Processing Record 31 of Set 1 | cidreira
# Processing Record 32 of Set 1 | talnakh
# Processing Record 33 of Set 1 | hobart
# Processing Record 34 of Set 1 | araouane
# Processing Record 35 of Set 1 | lebu
# Processing Record 36 of Set 1 | kholtoson
# Processing Record 37 of Set 1 | sao joao da barra
# Processing Record 38 of Set 1 | saint-francois
# Processing Record 39 of Set 1 | meulaboh
# Processing Record 40 of Set 1 | bethel
# Processing Record 41 of Set 1 | hermanus
# Processing Record 42 of Set 1 | flinders
# Processing Record 43 of Set 1 | lincoln
# Processing Record 44 of Set 1 | sabang
# Processing Record 45 of Set 1 | barrow
# Processing Record 46 of Set 1 | yellowknife
# Processing Record 47 of Set 1 | shitanjing
# Processing Record 48 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 49 of Set 1 | east london
# Processing Record 50 of Set 1 | watertown
# Processing Record 1 of Set 2 | cherskiy
# Processing Record 2 of Set 2 | sadiqabad
# Processing Record 3 of Set 2 | richards bay
# Processing Record 4 of Set 2 | castro
# Processing Record 5 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 6 of Set 2 | sibu
# Processing Record 7 of Set 2 | belyy yar
# Processing Record 8 of Set 2 | severo-kurilsk
# Processing Record 9 of Set 2 | atuona
# Processing Record 10 of Set 2 | lavrentiya
# Processing Record 11 of Set 2 | mantua
# Processing Record 12 of Set 2 | nikolskoye
# Processing Record 13 of Set 2 | saint-andre-avellin
# Processing Record 14 of Set 2 | jamestown
# Processing Record 15 of Set 2 | bambous virieux
# Processing Record 16 of Set 2 | pangody
# Processing Record 17 of Set 2 | lorengau
# Processing Record 18 of Set 2 | albany
# Processing Record 19 of Set 2 | taoudenni
# Processing Record 20 of Set 2 | hasaki
# Processing Record 21 of Set 2 | tsumeb
# Processing Record 22 of Set 2 | bolshoye selo
# Processing Record 23 of Set 2 | ereymentau
# Processing Record 24 of Set 2 | kununurra
# Processing Record 25 of Set 2 | wattegama
# Processing Record 26 of Set 2 | isangel
# Processing Record 27 of Set 2 | lasa
# Processing Record 28 of Set 2 | sitka
# Processing Record 29 of Set 2 | pringsewu
# Processing Record 30 of Set 2 | belaya gora
# Processing Record 31 of Set 2 | tuktoyaktuk
# Processing Record 32 of Set 2 | faanui
# Processing Record 33 of Set 2 | viedma
# Processing Record 34 of Set 2 | tiksi
# Processing Record 35 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 36 of Set 2 | sao francisco
# Processing Record 37 of Set 2 | liwonde
# Processing Record 38 of Set 2 | hambantota
# Processing Record 39 of Set 2 | torbay
# Processing Record 40 of Set 2 | jining
# Processing Record 41 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 42 of Set 2 | vinh long
# Processing Record 43 of Set 2 | kemijarvi
# Processing Record 44 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 45 of Set 2 | arrecife
# Processing Record 46 of Set 2 | new norfolk
# Processing Record 47 of Set 2 | sakakah
# Processing Record 48 of Set 2 | georgetown
# Processing Record 49 of Set 2 | paralimni
# Processing Record 50 of Set 2 | tabou
# Processing Record 1 of Set 3 | aykhal
# Processing Record 2 of Set 3 | khunti
# Processing Record 3 of Set 3 | hamilton
# Processing Record 4 of Set 3 | freeport
# Processing Record 5 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 6 of Set 3 | roald
# Processing Record 7 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 8 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 9 of Set 3 | tazmalt
# Processing Record 10 of Set 3 | bouca
# Processing Record 11 of Set 3 | odoyev
# Processing Record 12 of Set 3 | upernavik
# Processing Record 13 of Set 3 | bredasdorp
# Processing Record 14 of Set 3 | panaba
# Processing Record 15 of Set 3 | mataura
# Processing Record 16 of Set 3 | ayaviri
# Processing Record 17 of Set 3 | port elizabeth
# Processing Record 18 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 19 of Set 3 | mirnyy
# Processing Record 20 of Set 3 | constitucion
# Processing Record 21 of Set 3 | mitu
# Processing Record 22 of Set 3 | hithadhoo
# Processing Record 23 of Set 3 | palaikastron
# Processing Record 24 of Set 3 | luderitz
# Processing Record 25 of Set 3 | samsun
# Processing Record 26 of Set 3 | sharjah
# Processing Record 27 of Set 3 | avarua
# Processing Record 28 of Set 3 | san pedro
# Processing Record 29 of Set 3 | ust-koksa
# Processing Record 30 of Set 3 | aflu
# City not found. Skipping...
# Processing Record 31 of Set 3 | tamboril
# Processing Record 32 of Set 3 | bubaque
# Processing Record 33 of Set 3 | vaini
# Processing Record 34 of Set 3 | falmouth
# Processing Record 35 of Set 3 | acarau
# Processing Record 36 of Set 3 | maxixe
# Processing Record 37 of Set 3 | alofi
# Processing Record 38 of Set 3 | mount pleasant
# Processing Record 39 of Set 3 | marsh harbour
# Processing Record 40 of Set 3 | cuiluan
# Processing Record 41 of Set 3 | atambua
# Processing Record 42 of Set 3 | miles city
# Processing Record 43 of Set 3 | henties bay
# Processing Record 44 of Set 3 | leningradskiy
# Processing Record 45 of Set 3 | dikson
# Processing Record 46 of Set 3 | asau
# Processing Record 47 of Set 3 | bull savanna
# Processing Record 48 of Set 3 | ngukurr
# City not found. Skipping...
# Processing Record 49 of Set 3 | souillac
# Processing Record 50 of Set 3 | bengkulu
# Processing Record 1 of Set 4 | nuevo progreso
# Processing Record 2 of Set 4 | gizo
# Processing Record 3 of Set 4 | bentiu
# Processing Record 4 of Set 4 | tome
# Processing Record 5 of Set 4 | saint george
# Processing Record 6 of Set 4 | waipawa
# Processing Record 7 of Set 4 | margate
# Processing Record 8 of Set 4 | adrar
# Processing Record 9 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 10 of Set 4 | moussoro
# Processing Record 11 of Set 4 | charters towers
# Processing Record 12 of Set 4 | san patricio
# Processing Record 13 of Set 4 | belozerskoye
# Processing Record 14 of Set 4 | moron
# Processing Record 15 of Set 4 | kahului
# Processing Record 16 of Set 4 | sistranda
# Processing Record 17 of Set 4 | praia da vitoria
# Processing Record 18 of Set 4 | xai-xai
# Processing Record 19 of Set 4 | khatanga
# Processing Record 20 of Set 4 | mana
# Processing Record 21 of Set 4 | labuan
# Processing Record 22 of Set 4 | koumac
# Processing Record 23 of Set 4 | tiznit
# Processing Record 24 of Set 4 | yingkou
# Processing Record 25 of Set 4 | nhulunbuy
# Processing Record 26 of Set 4 | paramonga
# Processing Record 27 of Set 4 | shenkursk
# Processing Record 28 of Set 4 | ola
# Processing Record 29 of Set 4 | kjollefjord
# Processing Record 30 of Set 4 | ribeira grande
# Processing Record 31 of Set 4 | barawe
# City not found. Skipping...
# Processing Record 32 of Set 4 | mount gambier
# Processing Record 33 of Set 4 | benguela
# Processing Record 34 of Set 4 | jiaocheng
# Processing Record 35 of Set 4 | hualmay
# Processing Record 36 of Set 4 | porto santo
# Processing Record 37 of Set 4 | mujiayingzi
# Processing Record 38 of Set 4 | tasiilaq
# Processing Record 39 of Set 4 | dedougou
# Processing Record 40 of Set 4 | iskateley
# Processing Record 41 of Set 4 | brae
# Processing Record 42 of Set 4 | sola
# Processing Record 43 of Set 4 | ostrovnoy
# Processing Record 44 of Set 4 | sao filipe
# Processing Record 45 of Set 4 | qaanaaq
# Processing Record 46 of Set 4 | yaan
# Processing Record 47 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 48 of Set 4 | butaritari
# Processing Record 49 of Set 4 | la rioja
# Processing Record 50 of Set 4 | clyde river
# Processing Record 1 of Set 5 | kuche
# City not found. Skipping...
# Processing Record 2 of Set 5 | mahebourg
# Processing Record 3 of Set 5 | nguruka
# Processing Record 4 of Set 5 | la ronge
# Processing Record 5 of Set 5 | kuching
# Processing Record 6 of Set 5 | carnarvon
# Processing Record 7 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 8 of Set 5 | port macquarie
# Processing Record 9 of Set 5 | rungata
# City not found. Skipping...
# Processing Record 10 of Set 5 | mogadishu
# Processing Record 11 of Set 5 | saldanha
# Processing Record 12 of Set 5 | chagda
# City not found. Skipping...
# Processing Record 13 of Set 5 | tynda
# Processing Record 14 of Set 5 | kaitangata
# Processing Record 15 of Set 5 | qasigiannguit
# Processing Record 16 of Set 5 | thomaston
# Processing Record 17 of Set 5 | vila franca do campo
# Processing Record 18 of Set 5 | acapulco
# Processing Record 19 of Set 5 | kavaratti
# Processing Record 20 of Set 5 | port-de-paix
# City not found. Skipping...
# Processing Record 21 of Set 5 | saint-philippe
# Processing Record 22 of Set 5 | quatre cocos
# Processing Record 23 of Set 5 | chuy
# Processing Record 24 of Set 5 | bara
# Processing Record 25 of Set 5 | xiamen
# Processing Record 26 of Set 5 | lata
# Processing Record 27 of Set 5 | acuna
# City not found. Skipping...
# Processing Record 28 of Set 5 | sioux lookout
# Processing Record 29 of Set 5 | marawi
# Processing Record 30 of Set 5 | soure
# Processing Record 31 of Set 5 | port-gentil
# Processing Record 32 of Set 5 | esperance
# Processing Record 33 of Set 5 | toamasina
# Processing Record 34 of Set 5 | vestmannaeyjar
# Processing Record 35 of Set 5 | fare
# Processing Record 36 of Set 5 | vaitape
# Processing Record 37 of Set 5 | verkhoyansk
# Processing Record 38 of Set 5 | pasni
# Processing Record 39 of Set 5 | gat
# Processing Record 40 of Set 5 | komsomolskiy
# Processing Record 41 of Set 5 | monster
# Processing Record 42 of Set 5 | los llanos de aridane
# Processing Record 43 of Set 5 | berlevag
# Processing Record 44 of Set 5 | cayenne
# Processing Record 45 of Set 5 | zwedru
# Processing Record 46 of Set 5 | ondjiva
# Processing Record 47 of Set 5 | arraial do cabo
# Processing Record 48 of Set 5 | ponnani
# Processing Record 49 of Set 5 | saint-jean-de-braye
# Processing Record 50 of Set 5 | baringo
# Processing Record 1 of Set 6 | codrington
# Processing Record 2 of Set 6 | chokurdakh
# Processing Record 3 of Set 6 | katsuura
# Processing Record 4 of Set 6 | lakes entrance
# Processing Record 5 of Set 6 | mehran
# Processing Record 6 of Set 6 | terdal
# Processing Record 7 of Set 6 | kapaa
# Processing Record 8 of Set 6 | tuatapere
# Processing Record 9 of Set 6 | tecoanapa
# Processing Record 10 of Set 6 | olavarria
# Processing Record 11 of Set 6 | stromness
# Processing Record 12 of Set 6 | caravelas
# Processing Record 13 of Set 6 | charlestown
# Processing Record 14 of Set 6 | kysyl-syr
# Processing Record 15 of Set 6 | myski
# Processing Record 16 of Set 6 | burica
# City not found. Skipping...
# Processing Record 17 of Set 6 | dianopolis
# City not found. Skipping...
# Processing Record 18 of Set 6 | sept-iles
# Processing Record 19 of Set 6 | namibe
# Processing Record 20 of Set 6 | meyungs
# City not found. Skipping...
# Processing Record 21 of Set 6 | huangchuan
# Processing Record 22 of Set 6 | cuicatlan
# Processing Record 23 of Set 6 | nacala
# Processing Record 24 of Set 6 | kodiak
# Processing Record 25 of Set 6 | xinqing
# Processing Record 26 of Set 6 | coihaique
# Processing Record 27 of Set 6 | honolulu
# Processing Record 28 of Set 6 | norman wells
# Processing Record 29 of Set 6 | anicuns
# Processing Record 30 of Set 6 | weinan
# Processing Record 31 of Set 6 | denpasar
# Processing Record 32 of Set 6 | pauini
# Processing Record 33 of Set 6 | fort-shevchenko
# Processing Record 34 of Set 6 | honiara
# Processing Record 35 of Set 6 | goderich
# Processing Record 36 of Set 6 | ribeira brava
# Processing Record 37 of Set 6 | sembe
# Processing Record 38 of Set 6 | srednekolymsk
# Processing Record 39 of Set 6 | kavieng
# Processing Record 40 of Set 6 | ibra
# Processing Record 41 of Set 6 | tanout
# Processing Record 42 of Set 6 | san andres
# Processing Record 43 of Set 6 | airai
# Processing Record 44 of Set 6 | najran
# Processing Record 45 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 46 of Set 6 | ixtapa
# Processing Record 47 of Set 6 | suileng
# Processing Record 48 of Set 6 | eldorado
# Processing Record 49 of Set 6 | ulagan
# Processing Record 50 of Set 6 | inhambane
# Processing Record 1 of Set 7 | nicolas romero
# Processing Record 2 of Set 7 | deniliquin
# Processing Record 3 of Set 7 | jawor
# Processing Record 4 of Set 7 | xucheng
# Processing Record 5 of Set 7 | eureka
# Processing Record 6 of Set 7 | erenhot
# Processing Record 7 of Set 7 | kanalion
# Processing Record 8 of Set 7 | matara
# Processing Record 9 of Set 7 | bani walid
# Processing Record 10 of Set 7 | pisco
# Processing Record 11 of Set 7 | lazaro cardenas
# Processing Record 12 of Set 7 | bartica
# Processing Record 13 of Set 7 | antofagasta
# Processing Record 14 of Set 7 | ambilobe
# Processing Record 15 of Set 7 | ciudad bolivar
# Processing Record 16 of Set 7 | hervey bay
# Processing Record 17 of Set 7 | malakal
# Processing Record 18 of Set 7 | mbandaka
# Processing Record 19 of Set 7 | pevek
# Processing Record 20 of Set 7 | san jeronimo
# Processing Record 21 of Set 7 | cayhagan
# Processing Record 22 of Set 7 | altamont
# Processing Record 23 of Set 7 | moshenskoye
# Processing Record 24 of Set 7 | aksay
# Processing Record 25 of Set 7 | vila do maio
# Processing Record 26 of Set 7 | kesova gora
# Processing Record 27 of Set 7 | khandyga
# Processing Record 28 of Set 7 | fort nelson
# Processing Record 29 of Set 7 | dubbo
# Processing Record 30 of Set 7 | suntar
# Processing Record 31 of Set 7 | carroll
# Processing Record 32 of Set 7 | bang saphan
# Processing Record 33 of Set 7 | manakara
# Processing Record 34 of Set 7 | guerrero negro
# Processing Record 35 of Set 7 | tiarei
# Processing Record 36 of Set 7 | vardo
# Processing Record 37 of Set 7 | solovetskiy
# City not found. Skipping...
# Processing Record 38 of Set 7 | magadan
# Processing Record 39 of Set 7 | bosaso
# Processing Record 40 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 41 of Set 7 | mar del plata
# Processing Record 42 of Set 7 | kita
# Processing Record 43 of Set 7 | tselinnoye
# Processing Record 44 of Set 7 | saint-denis
# Processing Record 45 of Set 7 | iracoubo
# Processing Record 46 of Set 7 | malwan
# City not found. Skipping...
# Processing Record 47 of Set 7 | mauganj
# Processing Record 48 of Set 7 | sabha
# Processing Record 49 of Set 7 | touros
# Processing Record 50 of Set 7 | ponta delgada
# Processing Record 1 of Set 8 | karamea
# City not found. Skipping...
# Processing Record 2 of Set 8 | talara
# Processing Record 3 of Set 8 | maiduguri
# Processing Record 4 of Set 8 | kenai
# Processing Record 5 of Set 8 | shache
# Processing Record 6 of Set 8 | tacuarembo
# Processing Record 7 of Set 8 | toulepleu
# City not found. Skipping...
# Processing Record 8 of Set 8 | rosario de mora
# Processing Record 9 of Set 8 | mamallapuram
# Processing Record 10 of Set 8 | voi
# Processing Record 11 of Set 8 | chumikan
# Processing Record 12 of Set 8 | samarai
# Processing Record 13 of Set 8 | weymouth
# Processing Record 14 of Set 8 | sangar
# Processing Record 15 of Set 8 | maldonado
# Processing Record 16 of Set 8 | kilifi
# Processing Record 17 of Set 8 | vanimo
# Processing Record 18 of Set 8 | fukue
# Processing Record 19 of Set 8 | saint-pierre
# Processing Record 20 of Set 8 | casselman
# Processing Record 21 of Set 8 | imbituba
# Processing Record 22 of Set 8 | brigantine
# Processing Record 23 of Set 8 | mocambique
# City not found. Skipping...
# Processing Record 24 of Set 8 | rio gallegos
# Processing Record 25 of Set 8 | toliary
# City not found. Skipping...
# Processing Record 26 of Set 8 | salamiyah
# Processing Record 27 of Set 8 | hofn
# Processing Record 28 of Set 8 | dibulla
# Processing Record 29 of Set 8 | sai buri
# Processing Record 30 of Set 8 | cabo san lucas
# Processing Record 31 of Set 8 | khipro
# Processing Record 32 of Set 8 | jahrom
# City not found. Skipping...
# Processing Record 33 of Set 8 | hoquiam
# Processing Record 34 of Set 8 | provadija
# City not found. Skipping...
# Processing Record 35 of Set 8 | kondinskoye
# Processing Record 36 of Set 8 | iqaluit
# Processing Record 37 of Set 8 | broken hill
# Processing Record 38 of Set 8 | ugoofaaru
# Processing Record 39 of Set 8 | longyearbyen
# Processing Record 40 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 41 of Set 8 | mae sai
# Processing Record 42 of Set 8 | utiel
# Processing Record 43 of Set 8 | dutlwe
# Processing Record 44 of Set 8 | yulara
# Processing Record 45 of Set 8 | husavik
# Processing Record 46 of Set 8 | jumla
# Processing Record 47 of Set 8 | cukai
# Processing Record 48 of Set 8 | klaksvik
# Processing Record 49 of Set 8 | port hawkesbury
# Processing Record 50 of Set 8 | turbat
# Processing Record 1 of Set 9 | ijuin
# Processing Record 2 of Set 9 | polyarnyy
# Processing Record 3 of Set 9 | herveo
# Processing Record 4 of Set 9 | vila velha
# Processing Record 5 of Set 9 | axim
# Processing Record 6 of Set 9 | storsteinnes
# Processing Record 7 of Set 9 | aksarayskiy
# Processing Record 8 of Set 9 | progreso
# Processing Record 9 of Set 9 | narsaq
# Processing Record 10 of Set 9 | awash
# Processing Record 11 of Set 9 | uray
# Processing Record 12 of Set 9 | trairi
# Processing Record 13 of Set 9 | olinda
# Processing Record 14 of Set 9 | pokhvistnevo
# Processing Record 15 of Set 9 | banda aceh
# Processing Record 16 of Set 9 | manzhouli
# Processing Record 17 of Set 9 | saint-louis
# Processing Record 18 of Set 9 | atar
# Processing Record 19 of Set 9 | astana
# Processing Record 20 of Set 9 | dingle
# Processing Record 21 of Set 9 | naze
# Processing Record 22 of Set 9 | dunedin
# Processing Record 23 of Set 9 | tomatlan
# Processing Record 24 of Set 9 | vanavara
# Processing Record 25 of Set 9 | pangai
# Processing Record 26 of Set 9 | bonavista
# Processing Record 27 of Set 9 | stornoway
# Processing Record 28 of Set 9 | abiy adi
# City not found. Skipping...
# Processing Record 29 of Set 9 | merritt
# Processing Record 30 of Set 9 | sembakung
# Processing Record 31 of Set 9 | gamba
# Processing Record 32 of Set 9 | mashhad
# Processing Record 33 of Set 9 | genhe
# Processing Record 34 of Set 9 | lompoc
# Processing Record 35 of Set 9 | dabeiba
# Processing Record 36 of Set 9 | ust-tsilma
# Processing Record 37 of Set 9 | nome
# Processing Record 38 of Set 9 | kainantu
# Processing Record 39 of Set 9 | stanovoye
# Processing Record 40 of Set 9 | ust-omchug
# Processing Record 41 of Set 9 | tautira
# Processing Record 42 of Set 9 | cockburn town
# Processing Record 43 of Set 9 | kudahuvadhoo
# Processing Record 44 of Set 9 | trebukhiv
# Processing Record 45 of Set 9 | warqla
# City not found. Skipping...
# Processing Record 46 of Set 9 | glendive
# Processing Record 47 of Set 9 | grindavik
# Processing Record 48 of Set 9 | kijang
# Processing Record 49 of Set 9 | hirado
# Processing Record 50 of Set 9 | mazagao
# Processing Record 1 of Set 10 | swinoujscie
# Processing Record 2 of Set 10 | rawannawi
# City not found. Skipping...
# Processing Record 3 of Set 10 | grand centre
# City not found. Skipping...
# Processing Record 4 of Set 10 | victoria
# Processing Record 5 of Set 10 | dzilam gonzalez
# Processing Record 6 of Set 10 | san miguel
# Processing Record 7 of Set 10 | ulaangom
# Processing Record 8 of Set 10 | tambopata
# Processing Record 9 of Set 10 | kuandian
# Processing Record 10 of Set 10 | yinchuan
# Processing Record 11 of Set 10 | aksu
# Processing Record 12 of Set 10 | suchiapa
# Processing Record 13 of Set 10 | ambodifototra
# City not found. Skipping...
# Processing Record 14 of Set 10 | ahipara
# Processing Record 15 of Set 10 | andevoranto
# City not found. Skipping...
# Processing Record 16 of Set 10 | savanur
# Processing Record 17 of Set 10 | buala
# Processing Record 18 of Set 10 | yeniseysk
# Processing Record 19 of Set 10 | osa
# Processing Record 20 of Set 10 | youghal
# Processing Record 21 of Set 10 | camana
# Processing Record 22 of Set 10 | provideniya
# Processing Record 23 of Set 10 | hobyo
# Processing Record 24 of Set 10 | aswan
# Processing Record 25 of Set 10 | beloha
# Processing Record 26 of Set 10 | usinsk
# Processing Record 27 of Set 10 | jiwani
# Processing Record 28 of Set 10 | okato
# Processing Record 29 of Set 10 | namatanai
# Processing Record 30 of Set 10 | port hardy
# Processing Record 31 of Set 10 | siedlce
# Processing Record 32 of Set 10 | hirna
# Processing Record 33 of Set 10 | ostrov
# Processing Record 34 of Set 10 | mogadouro
# Processing Record 35 of Set 10 | myitkyina
# Processing Record 36 of Set 10 | buraydah
# Processing Record 37 of Set 10 | itarema
# Processing Record 38 of Set 10 | san carlos de bariloche
# Processing Record 39 of Set 10 | viligili
# City not found. Skipping...
# Processing Record 40 of Set 10 | hirata
# Processing Record 41 of Set 10 | rincon
# Processing Record 42 of Set 10 | auki
# Processing Record 43 of Set 10 | bandarbeyla
# Processing Record 44 of Set 10 | ust-ilimsk
# Processing Record 45 of Set 10 | balikpapan
# Processing Record 46 of Set 10 | tianpeng
# Processing Record 47 of Set 10 | rocha
# Processing Record 48 of Set 10 | porto recanati
# Processing Record 49 of Set 10 | zarya
# Processing Record 50 of Set 10 | sydney
# Processing Record 1 of Set 11 | wahran
# City not found. Skipping...
# Processing Record 2 of Set 11 | kampene
# Processing Record 3 of Set 11 | payo
# Processing Record 4 of Set 11 | sao jose da coroa grande
# Processing Record 5 of Set 11 | aksarka
# Processing Record 6 of Set 11 | iquique
# Processing Record 7 of Set 11 | biu
# Processing Record 8 of Set 11 | quang ngai
# Processing Record 9 of Set 11 | del rio
# Processing Record 10 of Set 11 | jamiltepec
# Processing Record 11 of Set 11 | puerto escondido
# Processing Record 12 of Set 11 | tura
# Processing Record 13 of Set 11 | bayangol
# Processing Record 14 of Set 11 | log
# Processing Record 15 of Set 11 | lengshuitan
# Processing Record 16 of Set 11 | varhaug
# Processing Record 17 of Set 11 | temaraia
# City not found. Skipping...
# Processing Record 18 of Set 11 | polikhnitos
# City not found. Skipping...
# Processing Record 19 of Set 11 | bilma
# Processing Record 20 of Set 11 | kristiinankaupunki
# Processing Record 21 of Set 11 | sahrak
# City not found. Skipping...
# Processing Record 22 of Set 11 | westport
# Processing Record 23 of Set 11 | adeje
# Processing Record 24 of Set 11 | harper
# Processing Record 25 of Set 11 | nouadhibou
# Processing Record 26 of Set 11 | sydney mines
# Processing Record 27 of Set 11 | sao felix do xingu
# Processing Record 28 of Set 11 | omboue
# Processing Record 29 of Set 11 | ishigaki
# Processing Record 30 of Set 11 | benjamin aceval
# Processing Record 31 of Set 11 | upata
# Processing Record 32 of Set 11 | monterrey
# Processing Record 33 of Set 11 | urucara
# Processing Record 34 of Set 11 | bichena
# Processing Record 35 of Set 11 | cehegin
# Processing Record 36 of Set 11 | vallenar
# Processing Record 37 of Set 11 | faya
# Processing Record 38 of Set 11 | yeppoon
# Processing Record 39 of Set 11 | goundam
# Processing Record 40 of Set 11 | lekoni
# Processing Record 41 of Set 11 | shimoda
# Processing Record 42 of Set 11 | tanggulangin
# Processing Record 43 of Set 11 | ornes
# Processing Record 44 of Set 11 | tamandare
# Processing Record 45 of Set 11 | yanan
# City not found. Skipping...
# Processing Record 46 of Set 11 | placido de castro
# Processing Record 47 of Set 11 | kuusamo
# Processing Record 48 of Set 11 | goulburn
# Processing Record 49 of Set 11 | lamu
# Processing Record 50 of Set 11 | querfurt
# Processing Record 1 of Set 12 | nanortalik
# Processing Record 2 of Set 12 | bonthe
# Processing Record 3 of Set 12 | eucaliptus
# Processing Record 4 of Set 12 | boone
# Processing Record 5 of Set 12 | asosa
# Processing Record 6 of Set 12 | north bend
# Processing Record 7 of Set 12 | karakendzha
# City not found. Skipping...
# Processing Record 8 of Set 12 | lodja
# Processing Record 9 of Set 12 | qarqin
# Processing Record 10 of Set 12 | erdaojiang
# Processing Record 11 of Set 12 | tocopilla
# Processing Record 12 of Set 12 | puerto el triunfo
# Processing Record 13 of Set 12 | turukhansk
# Processing Record 14 of Set 12 | ustyuzhna
# Processing Record 15 of Set 12 | vung tau
# Processing Record 16 of Set 12 | valparaiso
# Processing Record 17 of Set 12 | vitimskiy
# City not found. Skipping...
# Processing Record 18 of Set 12 | bereda
# Processing Record 19 of Set 12 | sonoita
# Processing Record 20 of Set 12 | deer lake
# Processing Record 21 of Set 12 | nishihara
# Processing Record 22 of Set 12 | erzin
# Processing Record 23 of Set 12 | raga
# Processing Record 24 of Set 12 | broome
# Processing Record 25 of Set 12 | mizdah
# Processing Record 26 of Set 12 | merauke
# Processing Record 27 of Set 12 | jiayuguan
# Processing Record 28 of Set 12 | kalianget
# Processing Record 29 of Set 12 | takoradi
# Processing Record 30 of Set 12 | marquard
# Processing Record 31 of Set 12 | great falls
# Processing Record 32 of Set 12 | ilulissat
# Processing Record 33 of Set 12 | surt
# Processing Record 34 of Set 12 | megion
# Processing Record 35 of Set 12 | oktyabrskiy
# Processing Record 36 of Set 12 | san ramon
# Processing Record 37 of Set 12 | karratha
# Processing Record 38 of Set 12 | sorvag
# City not found. Skipping...
# Processing Record 39 of Set 12 | paita
# Processing Record 40 of Set 12 | malinovoye ozero
# Processing Record 41 of Set 12 | pathein
# Processing Record 42 of Set 12 | naftah
# City not found. Skipping...
# Processing Record 43 of Set 12 | grootfontein
# Processing Record 44 of Set 12 | flin flon
# Processing Record 45 of Set 12 | fortuna
# Processing Record 46 of Set 12 | aquin
# Processing Record 47 of Set 12 | jiddah
# City not found. Skipping...
# Processing Record 48 of Set 12 | mahadday weyne
# City not found. Skipping...
# Processing Record 49 of Set 12 | tumannyy
# City not found. Skipping...
# Processing Record 50 of Set 12 | galle
# Processing Record 1 of Set 13 | terney
# Processing Record 2 of Set 13 | saint-augustin
# Processing Record 3 of Set 13 | khani
# Processing Record 4 of Set 13 | inyonga
# Processing Record 5 of Set 13 | xiazhen
# Processing Record 6 of Set 13 | omsukchan
# Processing Record 7 of Set 13 | babanusah
# City not found. Skipping...
# Processing Record 8 of Set 13 | lovington
# Processing Record 9 of Set 13 | paamiut
# Processing Record 10 of Set 13 | phaltan
# Processing Record 11 of Set 13 | coahuayana
# Processing Record 12 of Set 13 | batsfjord
# Processing Record 13 of Set 13 | nara
# Processing Record 14 of Set 13 | alekseyevskoye
# Processing Record 15 of Set 13 | havre-saint-pierre
# Processing Record 16 of Set 13 | bahar
# Processing Record 17 of Set 13 | port lincoln
# Processing Record 18 of Set 13 | tezu
# Processing Record 19 of Set 13 | carbonia
# Processing Record 20 of Set 13 | portland
# Processing Record 21 of Set 13 | burgersdorp
# Processing Record 22 of Set 13 | jinhua
# Processing Record 23 of Set 13 | miri
# Processing Record 24 of Set 13 | teya
# Processing Record 25 of Set 13 | puerto carreno
# Processing Record 26 of Set 13 | cabedelo
# Processing Record 27 of Set 13 | canutama
# Processing Record 28 of Set 13 | abilene
# Processing Record 29 of Set 13 | puerto madryn
# Processing Record 30 of Set 13 | funadhoo
# Processing Record 31 of Set 13 | vao
# Processing Record 32 of Set 13 | bhatkal
# Processing Record 33 of Set 13 | fairbanks
# Processing Record 34 of Set 13 | zeya
# Processing Record 35 of Set 13 | whitehorse
# Processing Record 36 of Set 13 | sangin
# Processing Record 37 of Set 13 | ruwi
# Processing Record 38 of Set 13 | whitefish
# Processing Record 39 of Set 13 | marrakesh
# Processing Record 40 of Set 13 | angoche
# Processing Record 41 of Set 13 | horodnytsya
# Processing Record 42 of Set 13 | erie
# Processing Record 43 of Set 13 | klaeng
# Processing Record 44 of Set 13 | bafoulabe
# Processing Record 45 of Set 13 | te anau
# Processing Record 46 of Set 13 | padang
# Processing Record 47 of Set 13 | phuket
# Processing Record 48 of Set 13 | robertsport
# Processing Record 49 of Set 13 | pimenta bueno
# Processing Record 50 of Set 13 | shenjiamen
# Processing Record 1 of Set 14 | puerto narino
# Processing Record 2 of Set 14 | amahai
# Processing Record 3 of Set 14 | ballangen
# Processing Record 4 of Set 14 | sao gabriel
# Processing Record 5 of Set 14 | bargal
# City not found. Skipping...
# Processing Record 6 of Set 14 | lagoa
# Processing Record 7 of Set 14 | juneau
# Processing Record 8 of Set 14 | zhovtneve
# Processing Record 9 of Set 14 | thinadhoo
# Processing Record 10 of Set 14 | marystown
# Processing Record 11 of Set 14 | monrovia
# Processing Record 12 of Set 14 | nimaparha
# Processing Record 13 of Set 14 | belem
# Processing Record 14 of Set 14 | louisbourg
# City not found. Skipping...
# Processing Record 15 of Set 14 | birao
# Processing Record 16 of Set 14 | anloga
# Processing Record 17 of Set 14 | port keats
# Processing Record 18 of Set 14 | raudeberg
# Processing Record 19 of Set 14 | boatlaname
# City not found. Skipping...
# Processing Record 20 of Set 14 | trindade
# Processing Record 21 of Set 14 | nikel
# Processing Record 22 of Set 14 | dukat
# Processing Record 23 of Set 14 | xichang
# Processing Record 24 of Set 14 | vylgort
# City not found. Skipping...
# Processing Record 25 of Set 14 | sao domingos
# Processing Record 26 of Set 14 | roma
# Processing Record 27 of Set 14 | tommot
# Processing Record 28 of Set 14 | kolpashevo
# Processing Record 29 of Set 14 | kibala
# Processing Record 30 of Set 14 | labuhan
# Processing Record 31 of Set 14 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 32 of Set 14 | westlock
# Processing Record 33 of Set 14 | voskresenskoye
# Processing Record 34 of Set 14 | baltiysk
# Processing Record 35 of Set 14 | hay river
# Processing Record 36 of Set 14 | agadez
# Processing Record 37 of Set 14 | kirishi
# Processing Record 38 of Set 14 | sikasso
# Processing Record 39 of Set 14 | paradwip
# City not found. Skipping...
# Processing Record 40 of Set 14 | yar-sale
# Processing Record 41 of Set 14 | tucuman
# Processing Record 42 of Set 14 | gibsons
# Processing Record 43 of Set 14 | lianzhou
# Processing Record 44 of Set 14 | gari
# Processing Record 45 of Set 14 | salamanca
# Processing Record 46 of Set 14 | saint-pacome
# City not found. Skipping...
# Processing Record 47 of Set 14 | new ulm
# Processing Record 48 of Set 14 | glenwood springs
# Processing Record 49 of Set 14 | porbandar
# Processing Record 50 of Set 14 | baracoa
# Processing Record 1 of Set 15 | pochutla
# Processing Record 2 of Set 15 | sinnamary
# Processing Record 3 of Set 15 | alta floresta
# Processing Record 4 of Set 15 | manzanillo
# Processing Record 5 of Set 15 | praia
# Processing Record 6 of Set 15 | moose factory
# Processing Record 7 of Set 15 | tarboro
# Processing Record 8 of Set 15 | aras
# Processing Record 9 of Set 15 | balkhash
# Processing Record 10 of Set 15 | colares
# Processing Record 11 of Set 15 | asfi
# Processing Record 12 of Set 15 | mittagong
# Processing Record 13 of Set 15 | montefiascone
# Processing Record 14 of Set 15 | rabaul
# Processing Record 15 of Set 15 | zhigansk
# Processing Record 16 of Set 15 | polunochnoye
# Processing Record 17 of Set 15 | batagay-alyta
# Processing Record 18 of Set 15 | bolshiye uki
# City not found. Skipping...
# Processing Record 19 of Set 15 | inzer
# Processing Record 20 of Set 15 | galgamacsa
# Processing Record 21 of Set 15 | samusu
# City not found. Skipping...
# Processing Record 22 of Set 15 | mora
# Processing Record 23 of Set 15 | levikha
# Processing Record 24 of Set 15 | namyslow
# Processing Record 25 of Set 15 | katobu
# Processing Record 26 of Set 15 | mayo
# Processing Record 27 of Set 15 | khormuj
# City not found. Skipping...
# Processing Record 28 of Set 15 | ballina
# Processing Record 29 of Set 15 | eldikan
# City not found. Skipping...
# Processing Record 30 of Set 15 | balabanovo
# Processing Record 31 of Set 15 | sampit
# Processing Record 32 of Set 15 | arlit
# Processing Record 33 of Set 15 | carutapera
# Processing Record 34 of Set 15 | pietersburg
# Processing Record 35 of Set 15 | pimentel
# Processing Record 36 of Set 15 | hare bay
# Processing Record 37 of Set 15 | aleysk
# Processing Record 38 of Set 15 | cervo
# Processing Record 39 of Set 15 | tateyama
# Processing Record 40 of Set 15 | singkang
# Processing Record 41 of Set 15 | finnsnes
# Processing Record 42 of Set 15 | darhan
# Processing Record 43 of Set 15 | paragominas
# Processing Record 44 of Set 15 | naron
# Processing Record 45 of Set 15 | gold coast
# Processing Record 46 of Set 15 | samandag
# Processing Record 47 of Set 15 | haian
# Processing Record 48 of Set 15 | bathsheba
# Processing Record 49 of Set 15 | pacific grove
# Processing Record 50 of Set 15 | liverpool
# Processing Record 1 of Set 16 | sao gabriel da cachoeira
# Processing Record 2 of Set 16 | prince rupert
# Processing Record 3 of Set 16 | porto velho
# Processing Record 4 of Set 16 | ossora
# Processing Record 5 of Set 16 | salvador
# Processing Record 6 of Set 16 | bonfim
# Processing Record 7 of Set 16 | baijiantan
# Processing Record 8 of Set 16 | painesville
# Processing Record 9 of Set 16 | huarmey
# Processing Record 10 of Set 16 | pangnirtung
# Processing Record 11 of Set 16 | kawalu
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Add the data to a new DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Thompson      CA  55.7435  -97.8558     46.56        87          75
# 1  Punta Arenas      CL -53.1500  -70.9167     33.91        69          75
# 2       Rikitea      PF -23.1203 -134.9692     69.28        71          99
# 3  Ponta Do Sol      PT  32.6667  -17.1000     70.43        62           0
# 4   Port Alfred      ZA -33.5906   26.8910     55.81        81          45
# 5         Bluff      NZ -46.6000  168.3333     47.80        75          93
# 6       Ushuaia      AR -54.8000  -68.3000     29.86        74          75
# 7     Hedensted      DK  55.7704    9.7011     56.89        94          49
# 8          Hilo      US  19.7297 -155.0900     80.33        79          20
# 9       Angoram      PG  -4.0625  144.0661     91.56        49          31
#
#    Wind Speed Current Description
# 0        0.00       broken clouds
# 1       17.27       broken clouds
# 2       21.88     overcast clouds
# 3        3.22           clear sky
# 4        4.63    scattered clouds
# 5       29.64          light rain
# 6       10.36       broken clouds
# 7       12.91    scattered clouds
# 8        6.91          few clouds
# 9        4.72    scattered clouds

# %%
# Export and save DataFrame as a CSV file
output_data_file = "WeatherPy_Database.csv"
# Export the City_data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
